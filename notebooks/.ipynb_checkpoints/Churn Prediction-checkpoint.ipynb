# %% [markdown]
# # Importing Libraries

# %%
# %%time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Embedding, Flatten, ReLU, LeakyReLU, PReLU, ELU, BatchNormalization, Dropout
from sklearn.metrics import confusion_matrix, accuracy_score
# Out:
# CPU times: total: 1.84 s
# Wall time: 9.92 s

# %% [markdown]
# # Reading Data

# %%
df = pd.read_csv("../data/Churn_Modelling.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# # Data Preprocessing

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.describe(include = "all")
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# count   10000.000000  10000.000000   10000.000000   10000.000000  10000.00000
# unique           NaN           NaN            NaN            NaN          NaN
# top              NaN           NaN            NaN            NaN          NaN
# freq             NaN           NaN            NaN            NaN          NaN
# mean       38.921800      5.012800   76485.889288       1.530200      0.70550
# std        10.487806      2.892174   62397.405202       0.581654      0.45584
# min        18.000000      0.000000       0.000000       1.000000      0.00000
# 25%        32.000000      3.000000       0.000000       1.000000      0.00000
# 50%        37.000000      5.000000   97198.540000       1.000000      1.00000
# 75%        44.000000      7.000000  127644.240000       2.000000      1.00000
# max        92.000000     10.000000  250898.090000       4.000000      1.00000
#
#         IsActiveMember  EstimatedSalary        Exited
# count     10000.000000     10000.000000  10000.000000
# unique             NaN              NaN           NaN
# top                NaN              NaN           NaN
# freq               NaN              NaN           NaN
# mean          0.515100    100090.239881      0.203700
# std           0.499797     57510.492818      0.402769
# min           0.000000        11.580000      0.000000
# 25%           0.000000     51002.110000      0.000000
# 50%           1.000000    100193.915000      0.000000
# 75%           1.000000    149388.247500      0.000000
# max           1.000000    199992.480000      1.000000

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %% [markdown]
# from tensorflow.keras.applications import --> All pretrained & SOTA models like VGG16, ResNet, etc.

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
geography = pd.get_dummies(df['Geography'], drop_first = True)
gender = pd.get_dummies(df['Gender'], drop_first = True)

# %%
df.drop(['Geography', 'Gender'], axis = 1, inplace = True)

# %%
dataset = pd.concat([df, geography, gender], axis = 1)
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602   Hargrave          619   42       2       0.00
# 1             2    15647311       Hill          608   41       1   83807.86
# 2             3    15619304       Onio          502   42       8  159660.80
# 3             4    15701354       Boni          699   39       1       0.00
# 4             5    15737888   Mitchell          850   43       2  125510.82
# ...         ...         ...        ...          ...  ...     ...        ...
# 9995       9996    15606229   Obijiaku          771   39       5       0.00
# 9996       9997    15569892  Johnstone          516   35      10   57369.61
# 9997       9998    15584532        Liu          709   36       7       0.00
# 9998       9999    15682355  Sabbatini          772   42       3   75075.31
# 9999      10000    15628319     Walker          792   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0                 1          1               1        101348.88       1
# 1                 1          0               1        112542.58       0
# 2                 3          1               0        113931.57       1
# 3                 2          0               0         93826.63       0
# 4                 1          1               1         79084.10       0
# ...             ...        ...             ...              ...     ...
# 9995              2          1               0         96270.64       0
# 9996              1          1               1        101699.77       0
# 9997              1          0               1         42085.58       1
# 9998              2          1               0         92888.52       1
# 9999              1          1               0         38190.78       0
#
#       Germany  Spain   Male
# 0       False  False  False
# 1       False   True  False
# 2       False  False  False
# 3       False  False  False
# 4       False   True  False
# ...       ...    ...    ...
# 9995    False  False   True
# 9996    False  False   True
# 9997    False  False  False
# 9998     True  False   True
# 9999    False  False  False
#
# [10000 rows x 15 columns]

# %%
dataset = dataset[['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Germany', 'Spain', 'Male', 'Exited']]
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602   Hargrave          619   42       2       0.00
# 1             2    15647311       Hill          608   41       1   83807.86
# 2             3    15619304       Onio          502   42       8  159660.80
# 3             4    15701354       Boni          699   39       1       0.00
# 4             5    15737888   Mitchell          850   43       2  125510.82
# ...         ...         ...        ...          ...  ...     ...        ...
# 9995       9996    15606229   Obijiaku          771   39       5       0.00
# 9996       9997    15569892  Johnstone          516   35      10   57369.61
# 9997       9998    15584532        Liu          709   36       7       0.00
# 9998       9999    15682355  Sabbatini          772   42       3   75075.31
# 9999      10000    15628319     Walker          792   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Germany  \
# 0                 1          1               1        101348.88    False
# 1                 1          0               1        112542.58    False
# 2                 3          1               0        113931.57    False
# 3                 2          0               0         93826.63    False
# 4                 1          1               1         79084.10    False
# ...             ...        ...             ...              ...      ...
# 9995              2          1               0         96270.64    False
# 9996              1          1               1        101699.77    False
# 9997              1          0               1         42085.58    False
# 9998              2          1               0         92888.52     True
# 9999              1          1               0         38190.78    False
#
#       Spain   Male  Exited
# 0     False  False       1
# 1      True  False       0
# 2     False  False       1
# 3     False  False       0
# 4      True  False       0
# ...     ...    ...     ...
# 9995  False   True       0
# 9996  False   True       0
# 9997  False  False       1
# 9998  False   True       1
# 9999  False  False       0
#
# [10000 rows x 15 columns]

# %%
dataset['EstimatedSalary'].mean()
# Out:
# 100090.239881

# %%
sns.boxplot(dataset['EstimatedSalary'])
# Out:
# <Axes: >

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Age              10000 non-null  int64
#  5   Tenure           10000 non-null  int64
#  6   Balance          10000 non-null  float64
#  7   NumOfProducts    10000 non-null  int64
#  8   HasCrCard        10000 non-null  int64
#  9   IsActiveMember   10000 non-null  int64
#  10  EstimatedSalary  10000 non-null  float64
#  11  Germany          10000 non-null  bool
#  12  Spain            10000 non-null  bool
#  13  Male             10000 non-null  bool
#  14  Exited           10000 non-null  int64
# dtypes: bool(3), float64(2), int64(9), object(1)
# memory usage: 966.9+ KB

# %% [markdown]
# # Splitting Dataset

# %%
X = dataset.iloc[:, 3:14]
y = dataset.iloc[:,14:]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1, stratify = y)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test  = sc.transform(X_test)

# %% [markdown]
# # Artificial Neural Network (ANN)

# %%
# Initializing the ANN, This is an empty neural network
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
# units/output dimension is the number of hidden neurons in the first layer
# kernel_initializer/init is the weight initialization parameter, where he_normal/he_uniform are the techniques
# While using relu as an activation function he_normal/he_uniform works well
# By using hyperparameter tuning, we'll find the exact number of hidden neurons, but now for initialization we used 6
classifier.add(Dense(units = 6, kernel_initializer= 'he_uniform', activation = 'relu', input_dim = 11))

# %%
# Adding the second hidden layer
# All the hidden layers must have RELU or LeakyRELU as the activation function,and relu prevents vanishing gradient
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform', activation = 'relu'))

# %%
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 72
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dense_2 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# %%time
# Fitting the ANN to the training dataset
# validation_split tests the model separately for the test dataset
model_history = classifier.fit(X_train, y_train, validation_split = 0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 6s 6ms/step - loss: 0.5797 - accuracy: 0.6999 - val_loss: 0.4829 - val_accuracy: 0.7842
# Epoch 2/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.4415 - accuracy: 0.8048 - val_loss: 0.4607 - val_accuracy: 0.7910
# Epoch 3/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.4257 - accuracy: 0.8127 - val_loss: 0.4473 - val_accuracy: 0.8008
# Epoch 4/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.4172 - accuracy: 0.8175 - val_loss: 0.4418 - val_accuracy: 0.8073
# Epoch 5/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.4111 - accuracy: 0.8214 - val_loss: 0.4337 - val_accuracy: 0.8133
# Epoch 6/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.4053 - accuracy: 0.8244 - val_loss: 0.4286 - val_accuracy: 0.8160
# Epoch 7/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.4005 - accuracy: 0.8257 - val_loss: 0.4249 - val_accuracy: 0.8198
# Epoch 8/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3954 - accuracy: 0.8272 - val_loss: 0.4190 - val_accuracy: 0.8209
# Epoch 9/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3907 - accuracy: 0.8309 - val_loss: 0.4149 - val_accuracy: 0.8217
# Epoch 10/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3837 - accuracy: 0.8352 - val_loss: 0.4059 - val_accuracy: 0.8281
# Epoch 11/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3754 - accuracy: 0.8442 - val_loss: 0.4001 - val_accuracy: 0.8304
# Epoch 12/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3664 - accuracy: 0.8475 - val_loss: 0.3895 - val_accuracy: 0.8334
# Epoch 13/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3590 - accuracy: 0.8535 - val_loss: 0.3828 - val_accuracy: 0.8372
# Epoch 14/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3532 - accuracy: 0.8541 - val_loss: 0.3779 - val_accuracy: 0.8368
# Epoch 15/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3492 - accuracy: 0.8563 - val_loss: 0.3708 - val_accuracy: 0.8429
# Epoch 16/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3462 - accuracy: 0.8535 - val_loss: 0.3668 - val_accuracy: 0.8444
# Epoch 17/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3445 - accuracy: 0.8571 - val_loss: 0.3631 - val_accuracy: 0.8444
# Epoch 18/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3422 - accuracy: 0.8578 - val_loss: 0.3629 - val_accuracy: 0.8429
# Epoch 19/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3411 - accuracy: 0.8574 - val_loss: 0.3598 - val_accuracy: 0.8451
# Epoch 20/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3405 - accuracy: 0.8576 - val_loss: 0.3618 - val_accuracy: 0.8455
# Epoch 21/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.
100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3268 - accuracy: 0.8647 - val_loss: 0.3532 - val_accuracy: 0.8535
# Epoch 83/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3262 - accuracy: 0.8653 - val_loss: 0.3533 - val_accuracy: 0.8531
# Epoch 84/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3266 - accuracy: 0.8662 - val_loss: 0.3541 - val_accuracy: 0.8516
# Epoch 85/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3264 - accuracy: 0.8656 - val_loss: 0.3531 - val_accuracy: 0.8523
# Epoch 86/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3261 - accuracy: 0.8651 - val_loss: 0.3539 - val_accuracy: 0.8512
# Epoch 87/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3252 - accuracy: 0.8671 - val_loss: 0.3576 - val_accuracy: 0.8478
# Epoch 88/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3262 - accuracy: 0.8651 - val_loss: 0.3532 - val_accuracy: 0.8516
# Epoch 89/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3259 - accuracy: 0.8632 - val_loss: 0.3537 - val_accuracy: 0.8519
# Epoch 90/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3262 - accuracy: 0.8655 - val_loss: 0.3526 - val_accuracy: 0.8512
# Epoch 91/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3260 - accuracy: 0.8645 - val_loss: 0.3520 - val_accuracy: 0.8501
# Epoch 92/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3256 - accuracy: 0.8666 - val_loss: 0.3557 - val_accuracy: 0.8523
# Epoch 93/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3254 - accuracy: 0.8658 - val_loss: 0.3546 - val_accuracy: 0.8501
# Epoch 94/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3258 - accuracy: 0.8668 - val_loss: 0.3533 - val_accuracy: 0.8497
# Epoch 95/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3255 - accuracy: 0.8660 - val_loss: 0.3515 - val_accuracy: 0.8512
# Epoch 96/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3260 - accuracy: 0.8670 - val_loss: 0.3541 - val_accuracy: 0.8508
# Epoch 97/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3254 - accuracy: 0.8638 - val_loss: 0.3524 - val_accuracy: 0.8504
# Epoch 98/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3255 - accuracy: 0.8662 - val_loss: 0.3521 - val_accuracy: 0.8519
# Epoch 99/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3256 - accuracy: 0.8655 - val_loss: 0.3540 - val_accuracy: 0.8516
# Epoch 100/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3251 - accuracy: 0.8651 - val_loss: 0.3542 - val_accuracy: 0.8508
# CPU times: total: 22min 45s
# Wall time: 4min 42s

# %%
# Making the predictions and testing the model
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 [==============================] - 1s 3ms/step

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1548,   45],
#        [ 232,  175]], dtype=int64)

# %%
# Calculating the accuracy
score = accuracy_score(y_pred, y_test)
score
# All accuracies are almost same
# Out:
# 0.8615

# %%
# List all data in history
print(model_history.history.keys())

# Summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc = 'upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # ANN with Third Hidden Layer

# %%
# Initializing the ANN, This is an empty neural network
classifier = Sequential()

# %%
# Adding the Input Layer and First Hidden layer
classifier.add(Dense(units = 10, kernel_initializer = 'he_normal', activation = 'relu', input_dim = 11))

# %%
# Adding Second Hidden Layer
classifier.add(Dense(units = 20, kernel_initializer = 'he_normal', activation = 'relu'))

# %%
# Adding Third Hidden layer
# By adding multiple layers there's a chance of Overfitting
classifier.add(Dense(units = 15, kernel_initializer = 'he_normal', activation = 'relu'))

# %%
# Adding the Output Layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 10)                120
#
#  dense_4 (Dense)             (None, 20)                220
#
#  dense_5 (Dense)             (None, 15)                315
#
#  dense_6 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 671
# Trainable params: 671
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# %%time
model_history = classifier.fit(X_train, y_train, validation_split = 0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 6s 7ms/step - loss: 0.4759 - accuracy: 0.7996 - val_loss: 0.4580 - val_accuracy: 0.8080
# Epoch 2/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.4110 - accuracy: 0.8296 - val_loss: 0.4292 - val_accuracy: 0.8247
# Epoch 3/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3877 - accuracy: 0.8399 - val_loss: 0.4115 - val_accuracy: 0.8300
# Epoch 4/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3691 - accuracy: 0.8487 - val_loss: 0.3995 - val_accuracy: 0.8357
# Epoch 5/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3564 - accuracy: 0.8489 - val_loss: 0.3834 - val_accuracy: 0.8398
# Epoch 6/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3480 - accuracy: 0.8565 - val_loss: 0.3734 - val_accuracy: 0.8448
# Epoch 7/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3387 - accuracy: 0.8632 - val_loss: 0.3686 - val_accuracy: 0.8440
# Epoch 8/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3361 - accuracy: 0.8617 - val_loss: 0.3644 - val_accuracy: 0.8432
# Epoch 9/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3317 - accuracy: 0.8645 - val_loss: 0.3719 - val_accuracy: 0.8440
# Epoch 10/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3300 - accuracy: 0.8634 - val_loss: 0.3688 - val_accuracy: 0.8478
# Epoch 11/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3272 - accuracy: 0.8683 - val_loss: 0.3635 - val_accuracy: 0.8489
# Epoch 12/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3266 - accuracy: 0.8638 - val_loss: 0.3608 - val_accuracy: 0.8478
# Epoch 13/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3229 - accuracy: 0.8666 - val_loss: 0.3639 - val_accuracy: 0.8482
# Epoch 14/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3245 - accuracy: 0.8662 - val_loss: 0.3623 - val_accuracy: 0.8493
# Epoch 15/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3219 - accuracy: 0.8673 - val_loss: 0.3600 - val_accuracy: 0.8501
# Epoch 16/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3211 - accuracy: 0.8683 - val_loss: 0.3595 - val_accuracy: 0.8508
# Epoch 17/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3200 - accuracy: 0.8688 - val_loss: 0.3622 - val_accuracy: 0.8497
# Epoch 18/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3188 - accuracy: 0.8694 - val_loss: 0.3595 - val_accuracy: 0.8508
# Epoch 19/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3180 - accuracy: 0.8679 - val_loss: 0.3618 - val_accuracy: 0.8516
# Epoch 20/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3166 - accuracy: 0.8673 - val_loss: 0.3631 - val_accuracy: 0.8489
# Epoch 21/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3160 - accuracy: 0.8724 - val_loss: 0.3696 - val_accuracy: 0.8501
# Epoch 22/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3155 - accuracy: 0.8711 - val_loss: 0.3620 - val_accuracy: 0.8538
# Epoch 23/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3135 - accuracy: 0.8701 - val_loss: 0.3622 - val_accuracy: 0.8497
# Epoch 24/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3139 - accuracy: 0.8683 - val_loss: 0.3687 - val_accuracy: 0.8512
# Epoch 25/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3125 - accuracy: 0.8714 - val_loss: 0.3630 - val_accuracy: 0.8527
# Epoch 26/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3110 - accuracy: 0.8742 - val_loss: 0.3642 - val_accuracy: 0.8501
# Epoch 27/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3115 - accuracy: 0.8709 - val_loss: 0.3750 - val_accuracy: 0.8504
# Epoch 28/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3117 - accuracy: 0.8716 - val_loss: 0.3635 - val_accuracy: 0.8523
# Epoch 29/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3100 - accuracy: 0.8712 - val_loss: 0.3678 - val_accuracy: 0.8516
# Epoch 30/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.
100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.2870 - accuracy: 0.8785 - val_loss: 0.3990 - val_accuracy: 0.8489
# Epoch 90/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.2872 - accuracy: 0.8808 - val_loss: 0.4042 - val_accuracy: 0.8436
# Epoch 91/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.2884 - accuracy: 0.8789 - val_loss: 0.3948 - val_accuracy: 0.8455
# Epoch 92/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.2859 - accuracy: 0.8824 - val_loss: 0.3958 - val_accuracy: 0.8357
# Epoch 93/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.2882 - accuracy: 0.8800 - val_loss: 0.3933 - val_accuracy: 0.8459
# Epoch 94/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.2873 - accuracy: 0.8770 - val_loss: 0.3995 - val_accuracy: 0.8379
# Epoch 95/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.2882 - accuracy: 0.8791 - val_loss: 0.3988 - val_accuracy: 0.8482
# Epoch 96/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.2863 - accuracy: 0.8776 - val_loss: 0.3980 - val_accuracy: 0.8504
# Epoch 97/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.2854 - accuracy: 0.8824 - val_loss: 0.4010 - val_accuracy: 0.8387
# Epoch 98/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.2866 - accuracy: 0.8828 - val_loss: 0.4014 - val_accuracy: 0.8360
# Epoch 99/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.2851 - accuracy: 0.8808 - val_loss: 0.3994 - val_accuracy: 0.8501
# Epoch 100/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.2854 - accuracy: 0.8817 - val_loss: 0.3987 - val_accuracy: 0.8379
# CPU times: total: 24min 30s
# Wall time: 5min 8s

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 [==============================] - 0s 3ms/step

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1483,  110],
#        [ 196,  211]], dtype=int64)

# %%
# This time after adding the third layer we can see that train & validation accuracy has increased, but test has decreased
score = accuracy_score(y_pred, y_test)
score
# Out:
# 0.847

# %%
# List all data in history
print(model_history.history.keys())

# Summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc = 'upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # ANN with Third Hidden layer and Dropout Layer

# %%
classifier = Sequential()

# %%
# Adding the Input Layer and First Hidden layer
classifier.add(Dense(units = 10, kernel_initializer = 'he_normal', activation = 'relu', input_dim = 11))

# %%
# Later on we'll find the dropout values by using hyperparameter tuning
classifier.add(Dropout(0.3))

# %%
# Adding Second Hidden Layer
classifier.add(Dense(units = 20, kernel_initializer= 'he_normal', activation = 'relu'))

# %%
classifier.add(Dropout(0.4))

# %%
# Adding Third Hidden layer
classifier.add(Dense(units = 15, kernel_initializer = 'he_normal', activation = 'relu'))

# %%
classifier.add(Dropout(0.2))

# %%
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 10)                120
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_8 (Dense)             (None, 20)                220
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_9 (Dense)             (None, 15)                315
#
#  dropout_2 (Dropout)         (None, 15)                0
#
#  dense_10 (Dense)            (None, 1)                 16
#
# =================================================================
# Total params: 671
# Trainable params: 671
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# %%time
model_history = classifier.fit(X_train, y_train, validation_split= 0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 6s 6ms/step - loss: 0.6566 - accuracy: 0.7453 - val_loss: 0.5272 - val_accuracy: 0.7842
# Epoch 2/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.5379 - accuracy: 0.7927 - val_loss: 0.5116 - val_accuracy: 0.7842
# Epoch 3/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.5026 - accuracy: 0.8018 - val_loss: 0.4963 - val_accuracy: 0.7842
# Epoch 4/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.4832 - accuracy: 0.8035 - val_loss: 0.4833 - val_accuracy: 0.7849
# Epoch 5/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.
100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3562 - accuracy: 0.8520 - val_loss: 0.3774 - val_accuracy: 0.8270
# Epoch 90/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3634 - accuracy: 0.8477 - val_loss: 0.3764 - val_accuracy: 0.8236
# Epoch 91/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3574 - accuracy: 0.8511 - val_loss: 0.3733 - val_accuracy: 0.8326
# Epoch 92/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3600 - accuracy: 0.8503 - val_loss: 0.3783 - val_accuracy: 0.8247
# Epoch 93/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3618 - accuracy: 0.8517 - val_loss: 0.3756 - val_accuracy: 0.8311
# Epoch 94/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3573 - accuracy: 0.8513 - val_loss: 0.3758 - val_accuracy: 0.8334
# Epoch 95/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3539 - accuracy: 0.8517 - val_loss: 0.3724 - val_accuracy: 0.8391
# Epoch 96/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3590 - accuracy: 0.8524 - val_loss: 0.3777 - val_accuracy: 0.8277
# Epoch 97/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3596 - accuracy: 0.8498 - val_loss: 0.3782 - val_accuracy: 0.8307
# Epoch 98/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3615 - accuracy: 0.8477 - val_loss: 0.3742 - val_accuracy: 0.8376
# Epoch 99/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3628 - accuracy: 0.8470 - val_loss: 0.3745 - val_accuracy: 0.8315
# Epoch 100/100
# 536/536 [==============================] - 3s 6ms/step - loss: 0.3576 - accuracy: 0.8518 - val_loss: 0.3748 - val_accuracy: 0.8323
# CPU times: total: 21min 48s
# Wall time: 4min 37s

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 [==============================] - 0s 3ms/step

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1581,   12],
#        [ 313,   94]], dtype=int64)

# %%
score = accuracy_score(y_pred, y_test)
score
# Out:
# 0.8375

# %%
# List all data in history
print(model_history.history.keys())

# Summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc = 'upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # Hyperparameter Optimization

# %%
def create_model(layers, activation):
    # Initialising the model
    model = Sequential()
    for i, nodes in enumerate(layers):
        # For first layer we have to provide input dimensions
        if i == 0:
            model.add(Dense(nodes, input_dim = X_train.shape[1]))
            model.add(Activation(activation))
            model.add(Dropout(0.3))
        
        else:
            model.add(Dense(nodes))
            model.add(Activation(activation))
            model.add(Dropout(0.3))

    # Last layer will have only 1 output
    model.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))
    
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    
    return model

model = KerasClassifier(build_fn = create_model, verbose = 0)
# Out:
# C:\Users\Sanket\AppData\Local\Temp\ipykernel_6576\1135321518.py:23: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model, verbose = 0)

# %%
# %%time

# Iterations where 1combination is 1 neural network and the number is the number of neurons
layers = [[20], [20,40], [45,30,15]]

# There is a way for taking this layers as well will discuss later
activations = ['sigmoid', 'relu']
param_grid = dict(layers = layers, activation = activations, batch_size = [128, 256], epochs = [30])

# Creating dictionary of parameters
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = 5) #RandomizedSearchCV can also be used

grid_result = grid.fit(X_train, y_train)
# Out:
# CPU times: total: 22min 57s
# Wall time: 6min 28s

# %%
print(grid_result.best_score_, grid_result.best_params_)
# Out:
# 0.856374990940094 {'activation': 'relu', 'batch_size': 128, 'epochs': 30, 'layers': [45, 30, 15]}

# %%
pred_y = grid.predict(X_test)
y_pred = (pred_y > 0.5)
# Out:
# 63/63 [==============================] - 0s 3ms/step

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1525,   68],
#        [ 217,  190]], dtype=int64)

# %%
score = accuracy_score(y_pred, y_test)
score
# Out:
# 0.8575

# %%
# List all data in history
print(model_history.history.keys())

# Summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc = 'upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
